# %%
#Import dependencies
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats =np.random.uniform(low=-90.000,high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size =2000)
lat_lngs =zip(lats,lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list
coordinates = list(lat_lngs)

# %%
# Import the request library
import requests

#Import the API key
from config import api_key

#Import the datetime module from the datetime library
from datetime import datetime
from citipy import citipy

# %%
# Create a list for holdimg the cities.
cities =[]
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    #If the city is unique, then we will ad it to the cities list.
    if city not in cities:
        cities.append(city)
#print the city count to confirm sufficient count.
len(cities)
# Out:
# 603

# %%
# Starting URL for Weather Map API Call
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=5c2fc058877ec11479f7c814c4b09de0

# %%
city_data =[]
#print the beginning of the logging
print("Begining Data Retrieval        ")
print("--------------------------------")

#Create counters
record_count = 1
set_count =1

#Loop through all the cities in our list
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50== 0 and i >=50):
        set_count +=1
        record_count =1
    # Create endpoint URL with each city
    city_url =url + "&q=" + "i"
# Loop through all the cities in the list.
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes.
    if(i % 50 ==0 and i >=50):
        set_count +=1
        record_count =1
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count
    record_count +=1 
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
    
    # Convert the date to ISO standard.
        #city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
    #Appnd the city information into city_data list.
        city_data.append({"City": city.title(),
                    "Country": city_country,
                     "Lat": city_lat,
                     "Lng":city_lng,
                     "Max Temp": city_max_temp,
                     "Humidity": city_humidity,
                     "Cloudiness": city_clouds,
                     "Wind Speed":city_wind,
                     "Current Description": city_description})
    
    #If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass
    # Indicate that Data loading is complete.
    print("-------------------------------")
    print("Data Retrieval Complete        ")
    print("-------------------------------")
# Out:
# Begining Data Retrieval
# --------------------------------
# processing Record 1 of Set 13 | mar del plata
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 13 | presidencia roque saenz pena
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 13 | new norfolk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 13 | chagda
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 13 | denpasar
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 13 | namatanai
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 13 | hermanus
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 13 | emerald
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 13 | puerto ayora
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 13 | pemangkat
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 13 | ushuaia
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 13 | barentsburg
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 13 | hobart
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 13 | alamosa
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 13 | bambous virieux
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 13 | trairi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 13 | dikson
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 13 | manggar
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 13 | mae sai
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 13 | pevek
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 13 | punta arenas
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 13 | sento se
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 13 | rikitea
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 13 | bengkulu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 13 | port alfred
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 13 | san patricio
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 13 | villamaria
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 13 | shebunino
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 13 | ilave
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 13 | venice
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 13 | namibe
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 13 | arraial do cabo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 13 | tura
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 13 | lebu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 13 | touros
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 13 | sitka
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 13 | izumo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 13 | goshen
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 13 | vastervik
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 4 of Set 24 | matagami
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 5 of Set 24 | bulawayo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 6 of Set 24 | yeppoon
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 7 of Set 24 | chara
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 8 of Set 24 | ahuimanu
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 9 of Set 24 | gardez
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 10 of Set 24 | baturaja
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 11 of Set 24 | abu kamal
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 12 of Set 24 | baykit
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 13 of Set 24 | homer
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 14 of Set 24 | vestmanna
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 15 of Set 24 | canavieiras
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 16 of Set 24 | carballo
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 17 of Set 24 | plaster rock
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 18 of Set 24 | tautira
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 19 of Set 24 | dharchula
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 20 of Set 24 | turukhansk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 21 of Set 24 | celestun
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 22 of Set 24 | coos bay
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 23 of Set 24 | puerto colombia
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 24 of Set 24 | urucui
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 25 of Set 24 | kahului
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 26 of Set 24 | shahreza
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 27 of Set 24 | tuy hoa
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 28 of Set 24 | kargasok
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 29 of Set 24 | marsa matruh
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 30 of Set 24 | manzhouli
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 31 of Set 24 | rudnogorsk
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 32 of Set 24 | sidi ali
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 33 of Set 24 | loviisa
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 34 of Set 24 | alofi
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 35 of Set 24 | goma
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 36 of Set 24 | datong
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 37 of Set 24 | okha
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 38 of Set 24 | luino
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 39 of Set 24 | stokmarknes
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 40 of Set 24 | chihuahua
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 41 of Set 24 | daru
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 42 of Set 24 | maghama
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 43 of Set 24 | ust-kamchatsk
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 44 of Set 24 | taoudenni
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 45 of Set 24 | willmar
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 46 of Set 24 | camabatela
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 47 of Set 24 | parintins
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 48 of Set 24 | komsomolskiy
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 49 of Set 24 | lolua
# City not found. Skipping...
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 50 of Set 24 | inhambane
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 1 of Set 25 | kununurra
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 2 of Set 25 | nouadhibou
# -------------------------------
# Data Retrieval Complete
# -------------------------------
# processing Record 3 of Set 25 | tecoanapa
# -------------------------------
# Data Retrieval Complete
# -------------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                            City Country    Lat     Lng  Max Temp  Humidity  \
# 0                 Mar Del Plata      AR -38.00  -57.56     60.80        48
# 1  Presidencia Roque Saenz Pena      AR -26.79  -60.44     74.95        46
# 2                   New Norfolk      AU -42.78  147.06     53.01        93
# 3                      Denpasar      ID  -8.65  115.22     80.60       100
# 4                     Namatanai      PG  -3.67  152.43     80.15        81
# 5                      Hermanus      ZA -34.42   19.23     60.01        61
# 6                       Emerald      AU -23.53  148.17     77.00        22
# 7                  Puerto Ayora      EC  -0.74  -90.35     71.60        78
# 8                     Pemangkat      ID   1.17  108.97     80.13        80
# 9                       Ushuaia      AR -54.80  -68.30     55.40        43
#
#    Cloudiness  Wind Speed Current Description
# 0          40       13.87    scattered clouds
# 1          96       11.30     overcast clouds
# 2         100        3.27          light rain
# 3          40       10.29          light rain
# 4         100        8.95       moderate rain
# 5          58        3.00       broken clouds
# 6          13       11.41          light rain
# 7          75       18.34       broken clouds
# 8         100        6.49     overcast clouds
# 9          40       14.99    scattered clouds

# %%
# Create the output file (CSV).
output_data_file = "Weather_Database.csv"
# Export the City_Data into CSV

city_data_df.to_csv(output_data_file,index_label="City_ID")
